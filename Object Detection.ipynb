# %%
import tkinter as tk
from tkinter import filedialog
from ultralytics import YOLO
import cv2

# Create a function to perform object detection
def perform_object_detection():
    # Load the YOLO model
    model = YOLO("yolov8s.pt")
    
    # Open a file dialog for the user to select an image file
    file_path = filedialog.askopenfilename()
    
    # Check if a file was selected
    if file_path:
        # Perform object detection on the selected image
        results = model.predict(source=file_path, show=True, conf=0.4, save=True)

# Create the main application window
root = tk.Tk()
root.title("Object Detection GUI")

# Create a button to trigger object detection
detect_button = tk.Button(root, text="Detect Objects", command=perform_object_detection)
detect_button.pack(pady=20)

# Create a label to display results (if needed)
# result_label = tk.Label(root, text="", wraplength=300)
# result_label.pack()

# Start the main event loop
root.mainloop()
# Out:
# WARNING  Environment does not support cv2.imshow() or PIL Image.show()
# OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
#
#
# image 1/1 C:\Users\NIKSHA MAHAJAN\Documents\Apowersoft\Windows ApowerMirror\20231222_121452.png: 320x640 1 person, 1 bottle, 2 chairs, 1 dining table, 1 cell phone, 1 book, 653.0ms
# Speed: 5.0ms preprocess, 653.0ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs\detect\predict26

# %%
# import tkinter as tk
# from tkinter import ttk
# import cv2
# from ultralytics import YOLO
# from datasets import load_dataset

# dataset = load_dataset("fcakyon/gun-object-detection")

# # Load the YOLO model
# model = YOLO("yolov8s.pt")

# # Create a function to start real-time object detection
# def start_realtime_detection():
#     # Open a connection to the default camera (usually the built-in webcam)
# #     cap = cv2.VideoCapture(0)

#     def detect_objects():
#         ret, frame = cap.read()

#         if ret:
#             # Perform object detection on the frame
#             results = model(frame)

#             # Display the frame with detection results
#             frame_with_results = results.render()[0]
#             photo = cv2.cvtColor(frame_with_results, cv2.COLOR_BGR2RGB)
#             image = Image.fromarray(photo)
#             imgtk = ImageTk.PhotoImage(image=image)

#             video_label.imgtk = imgtk
#             video_label.configure(image=imgtk)

#             # Repeat the detection
#             video_label.after(10, detect_objects)

#     detect_objects()

# # Create the main application window
# root = tk.Tk()
# root.title("Real-time Object Detection")

# # Create a button to start real-time detection
# start_button = ttk.Button(root, text="Start Real-time Detection", command=start_realtime_detection)
# start_button.pack(pady=20)

# # Create a label to display the video feed
# video_label = ttk.Label(root)
# video_label.pack()

# # Start the main event loop
# root.mainloop()

# %%
# import tkinter as tk
# from tkinter import ttk
# import cv2
# from ultralytics import YOLO
# from datasets import load_dataset

# dataset = load_dataset("fcakyon/gun-object-detection")

# # Load the YOLO model
# model = YOLO("yolov8s.pt")

# # Create a function to start real-time object detection
# def start_realtime_detection():
#     # Open a connection to the default camera (usually the built-in webcam)
#     cap = cv2.VideoCapture(0)

#     def detect_objects(cap):
#         while True:
#             ret, frame = cap.read()

#             if not ret:
#                 break

#             # Perform object detection on the frame using the YOLO model
#             results = model(frame)

#             # Display the frame with detection results
#             frame_with_results = results.render()[0]
#             photo = cv2.cvtColor(frame_with_results, cv2.COLOR_BGR2RGB)
#             image = Image.fromarray(photo)
#             imgtk = ImageTk.PhotoImage(image=image)

#             video_label.imgtk = imgtk
#             video_label.configure(image=imgtk)

#             # Repeat the detection
#             root.update()  # Update the GUI window
#             root.after(10, detect_objects, cap)  # Call detect_objects function again

#     detect_objects(cap)

# # Create the main application window
# root = tk.Tk()
# root.title("Real-time Object Detection")

# # Create a button to start real-time detection
# start_button = ttk.Button(root, text="Start Real-time Detection", command=start_realtime_detection)
# start_button.pack(pady=20)

# # Create a label to display the video feed
# video_label = ttk.Label(root)
# video_label.pack()

# # Start the main event loop
# root.mainloop()

# %%
# import tkinter as tk
# from tkinter import ttk
# import cv2
# from ultralytics import YOLO


# # Load the YOLO model
# model = YOLO("yolov8s.pt")

# # Create a function to start real-time object detection
# def start_realtime_detection():
#     # Open a connection to the default camera (usually the built-in webcam)
#     cap = cv2.VideoCapture(0)

#     def detect_objects(cap):
#         while True:
#             ret, frame = cap.read()

#             if not ret:
#                 break

#             # Perform object detection on the frame using the YOLO model
#             results = model(frame)

#             # Iterate through the results and draw bounding boxes
#             for det in results.pred[0]:
#                 x1, y1, x2, y2, conf, class_id = det.tolist()
#                 if conf > 0.4:  # Filter detections by confidence threshold
#                     # Draw a bounding box on the frame
#                     cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
#                     # Display the class label and confidence
#                     label = f"Class {int(class_id)}: {conf:.2f}"
#                     cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#             # Display the frame with detection results
#             frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#             photo = ImageTk.PhotoImage(image=Image.fromarray(frame_rgb))
#             video_label.imgtk = photo
#             video_label.configure(image=photo)

#             # Update the GUI window
#             root.update()

#     detect_objects(cap)

# # Create the main application window
# root = tk.Tk()
# root.title("Real-time Object Detection")

# # Create a button to start real-time detection
# start_button = ttk.Button(root, text="Start Real-time Detection", command=start_realtime_detection)
# start_button.pack(pady=20)

# # Create a label to display the video feed
# video_label = ttk.Label(root)
# video_label.pack()

# # Start the main event loop
# root.mainloop()
# Out:
# 0: 480x640 1 person, 342.0ms
# Speed: 9.6ms preprocess, 342.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_11796\3599821336.py", line 47, in start_realtime_detection
#     detect_objects(cap)
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_11796\3599821336.py", line 29, in detect_objects
#     for det in results.pred[0]:
#                ^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'pred'
#
# 0: 480x640 1 person, 267.8ms
# Speed: 3.0ms preprocess, 267.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
# ...

# %%
# import tkinter as tk
# from tkinter import ttk
# import cv2
# from ultralytics import YOLO
# from PIL import Image, ImageTk
# from datasets import load_dataset

# dataset = load_dataset("fcakyon/gun-object-detection")


# # Load the YOLO model
# model = YOLO("yolov8s.pt")

# # Create a function to start real-time object detection
# def start_realtime_detection():
#     # Open a connection to the default camera (usually the built-in webcam)
#     cap = cv2.VideoCapture(0)

#     def detect_objects(cap):
#         while True:
#             ret, frame = cap.read()

#             if not ret:
#                 break

#             # Perform object detection on the frame using the YOLO model
#             results = model(frame)

#             # Extract detection results using results.xyxy[0]
#             detections = results.xyxy[0].cpu().numpy()

#             # Iterate through the detections
#             for det in detections:
#                 x1, y1, x2, y2, conf, class_id = det[:6]
#                 if conf > 0.4:  # Filter detections by confidence threshold
#                     # Draw a bounding box on the frame
#                     cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
#                     # Display the class label and confidence
#                     label = f"Class {int(class_id)}: {conf:.2f}"
#                     cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#             # Display the frame with detection results
#             frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#             photo = ImageTk.PhotoImage(image=Image.fromarray(frame_rgb))
#             video_label.imgtk = photo
#             video_label.configure(image=photo)

#             # Update the GUI window
#             root.update()

#     detect_objects(cap)

# # Create the main application window
# root = tk.Tk()
# root.title("Real-time Object Detection")

# # Create a button to start real-time detection
# start_button = ttk.Button(root, text="Start Real-time Detection", command=start_realtime_detection)
# start_button.pack(pady=20)

# # Create a label to display the video feed
# video_label = ttk.Label(root)
# video_label.pack()

# # Start the main event loop
# root.mainloop()
# Out:
# 0: 480x640 1 person, 355.5ms
# Speed: 11.6ms preprocess, 355.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_11796\929357862.py", line 51, in start_realtime_detection
#     detect_objects(cap)
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_11796\929357862.py", line 30, in detect_objects
#     detections = results.xyxy[0].cpu().numpy()
#                  ^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'xyxy'

# %%
# import tkinter as tk
# from tkinter import ttk
# import cv2
# from ultralytics import YOLO
# from PIL import Image, ImageTk
# from datasets import load_dataset  # Import the load_dataset function

# # Load the YOLO model
# model = YOLO("yolov8s.pt")

# # Load your custom dataset
# custom_dataset = load_dataset("fcakyon/gun-object-detection")  # Replace with the actual path

# # Create a function to start real-time object detection
# def start_realtime_detection():
#     # Open a connection to the default camera (usually the built-in webcam)
#     cap = cv2.VideoCapture(0)

#     def detect_objects():
#         while True:
#             ret, frame = cap.read()

#             if not ret:
#                 break

#             # Perform object detection on the frame using the YOLO model
#             results = model(frame)

#             # Iterate through the results and draw bounding boxes
#             for det in results.xyxy[0]:  # Use results.xyxy to access detections
#                 x1, y1, x2, y2, conf, class_id = det[:6]
#                 if conf > 0.4:  # Filter detections by confidence threshold
#                     # Draw a bounding box on the frame
#                     cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
#                     # Display the class label and confidence
#                     label = f"Class {int(class_id)}: {conf:.2f}"
#                     cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#             # Display the frame with detection results
#             frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#             photo = ImageTk.PhotoImage(image=Image.fromarray(frame_rgb))
#             video_label.imgtk = photo
#             video_label.configure(image=photo)

#             # Update the GUI window
#             root.update()

#     detect_objects()

# # Create the main application window
# root = tk.Tk()
# root.title("Real-time Object Detection")

# # Create a button to start real-time detection
# start_button = ttk.Button(root, text="Start Real-time Detection", command=start_realtime_detection)
# start_button.pack(pady=20)

# # Create a label to display the video feed
# video_label = ttk.Label(root)
# video_label.pack()

# # Start the main event loop
# root.mainloop()
# Out:
# 0: 480x640 1 person, 331.8ms
# Speed: 3.2ms preprocess, 331.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_11796\4119299132.py", line 48, in start_realtime_detection
#     detect_objects()
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_11796\4119299132.py", line 30, in detect_objects
#     for det in results.xyxy[0]:  # Use results.xyxy to access detections
#                ^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'xyxy'

# %%
# import tkinter as tk
# from tkinter import ttk
# import cv2
# from ultralytics import YOLO
# from PIL import Image, ImageTk
# from datasets import load_dataset  # Import the load_dataset function

# # Load the YOLO model
# model = YOLO("yolov8s.pt")

# # Load your custom dataset
# custom_dataset = load_dataset("fcakyon/gun-object-detection")  # Replace with the actual path

# # Create a function to start real-time object detection
# def start_realtime_detection():
#     # Open a connection to the default camera (usually the built-in webcam)
#     cap = cv2.VideoCapture(0)

#     def detect_objects():
#         while True:
#             ret, frame = cap.read()

#             if not ret:
#                 break

#             # Perform object detection on the frame using the YOLO model
#             results = model(frame)

#             # Iterate through the results and draw bounding boxes
#             for det in results.pred[0]:  # Use results.pred to access detections
#                 x1, y1, x2, y2, conf, class_id = det[:6]
#                 if conf > 0.4:  # Filter detections by confidence threshold
#                     # Draw a bounding box on the frame
#                     cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
#                     # Display the class label and confidence
#                     label = f"Class {int(class_id)}: {conf:.2f}"
#                     cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#             # Display the frame with detection results
#             frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#             photo = ImageTk.PhotoImage(image=Image.fromarray(frame_rgb))
#             video_label.imgtk = photo
#             video_label.configure(image=photo)

#             # Update the GUI window
#             root.update()

#     detect_objects()

# # Create the main application window
# root = tk.Tk()
# root.title("Real-time Object Detection")

# # Create a button to start real-time detection
# start_button = ttk.Button(root, text="Start Real-time Detection", command=start_realtime_detection)
# start_button.pack(pady=20)

# # Create a label to display the video feed
# video_label = ttk.Label(root)
# video_label.pack()

# # Start the main event loop
# root.mainloop()
# Out:
# 0: 480x640 1 person, 1 donut, 294.2ms
# Speed: 3.0ms preprocess, 294.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_11796\2224395142.py", line 48, in start_realtime_detection
#     detect_objects()
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_11796\2224395142.py", line 30, in detect_objects
#     for det in results.pred[0]:  # Use results.pred to access detections
#                ^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'pred'

# %%
# import tkinter as tk
# from tkinter import filedialog, Toplevel
# from ultralytics import YOLO
# import cv2
# from PIL import Image, ImageTk

# # Create a function to perform object detection and display the results
# def perform_object_detection():
#     # Load the YOLO model
#     model = YOLO("yolov8s.pt")
    
#     # Open a file dialog for the user to select an image file
#     file_path = filedialog.askopenfilename()
    
#     # Check if a file was selected
#     if file_path:
#         # Perform object detection on the selected image
#         results = model.predict(source=file_path, show=False, conf=0.4, save=True)
        
#         # Display the detected objects in a new window
#         display_results(results[0])

# # Create a function to display detection results in a new window
# def display_results(result):
#     # Create a new window
#     result_window = Toplevel(root)
#     result_window.title("Object Detection Results")
    
#     # Load the processed image with bounding boxes
#     processed_image_path = result[0]  # Access the processed image path directly
#     processed_image = cv2.imread(processed_image_path)
#     processed_image_rgb = cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB)
#     photo = ImageTk.PhotoImage(image=Image.fromarray(processed_image_rgb))
    
#     # Create a label to display the image
#     result_label = tk.Label(result_window, image=photo)
#     result_label.photo = photo  # Prevent the image from being garbage collected
#     result_label.pack()
# # Create the main application window
# root = tk.Tk()
# root.title("Object Detection GUI")

# # Create a button to trigger object detection
# detect_button = tk.Button(root, text="Detect Objects", command=perform_object_detection)
# detect_button.pack(pady=20)

# # Start the main event loop
# root.mainloop()
# Out:
# image 1/1 C:\Users\NIKSHA MAHAJAN\Pictures\Screenshots\Screenshot (127).png: 384x640 1 person, 243.1ms
# Speed: 3.0ms preprocess, 243.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict12
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_4348\527762095.py", line 21, in perform_object_detection
#     display_results(results[0])
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_4348\527762095.py", line 31, in display_results
#     processed_image = cv2.imread(processed_image_path)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\site-packages\ultralytics\utils\patches.py", line 26, in imread
# ...

# %%
# import tkinter as tk
# from tkinter import filedialog, Toplevel
# from ultralytics import YOLO
# import cv2
# from PIL import Image, ImageTk

# # Initialize the GUI
# root = tk.Tk()
# root.title("Object Detection GUI")

# # Create a function to perform object detection and display the results
# def perform_object_detection():
#     # Load the YOLO model
#     model = YOLO("yolov8s.pt")
    
#     # Open a file dialog for the user to select an image file
#     file_path = filedialog.askopenfilename()
    
#     # Check if a file was selected
#     if file_path:
#         # Perform object detection on the selected image
#         results = model.predict(source=file_path, show=False, conf=0.4, save=True)
        
#         # Display the detected objects in a new window
#         display_results(results[0])

# # Create a function to display detection results in a new window
# def detect_objects():
#     # Open a file dialog to select an image
#     file_path = filedialog.askopenfilename()
    
#     if file_path:
#         # Load and process the image using OpenCV
#         image = cv2.imread(file_path)
        
#         # Perform object detection here (using OpenCV, TensorFlow, or other libraries)
#         # ...

#         # Display the processed image with detected objects in the GUI
#         display_image(image)

# # Create a function to display the image in the GUI
# def display_image(image):
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     image = Image.fromarray(image)
#     photo = ImageTk.PhotoImage(image=image)

#     label = tk.Label(image=photo)
#     label.image = photo
#     label.pack()
# # Create a button to trigger object detection
# detect_button = tk.Button(root, text="Detect Objects", command=perform_object_detection)
# detect_button.pack(pady=20)

# # Start the main event loop
# root.mainloop()
# Out:
# image 1/1 C:\Users\NIKSHA MAHAJAN\Pictures\Screenshots\Screenshot (523).png: 384x640 6 knifes, 1 cake, 373.3ms
# Speed: 10.2ms preprocess, 373.3ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict13
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_8312\864892030.py", line 25, in perform_object_detection
#     display_results(results[0])
#     ^^^^^^^^^^^^^^^
# NameError: name 'display_results' is not defined

# %%
# import tkinter as tk
# from tkinter import filedialog
# from ultralytics import YOLO

# # Create a function to perform object detection
# def perform_object_detection():
#     # Load the YOLO model
#     model = YOLO("yolov8s.pt")
    
#     # Open a file dialog for the user to select an image file
#     file_path = filedialog.askopenfilename()
    
#     # Check if a file was selected
#     if file_path:
#         # Perform object detection on the selected image and display it
#         results = model.predict(source=file_path, show=True, conf=0.4, save=False)  # Set save=False to avoid saving images

# # Create the main application window
# root = tk.Tk()
# root.title("Object Detection GUI")

# # Create a button to trigger object detection
# detect_button = tk.Button(root, text="Detect Objects", command=perform_object_detection)
# detect_button.pack(pady=20)

# # Start the main event loop
# root.mainloop()
# Out:
# WARNING  Environment does not support cv2.imshow() or PIL Image.show()
# OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
#
#
# image 1/1 C:\Users\NIKSHA MAHAJAN\Pictures\Screenshots\Screenshot (480).png: 384x640 6 persons, 2 potted plants, 2 tvs, 309.1ms
# Speed: 3.5ms preprocess, 309.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
# import tkinter as tk
# from tkinter import filedialog
# from ultralytics import YOLO
# from PIL import Image, ImageTk
# import cv2
# import numpy as np

# # Create a function to perform object detection
# def perform_object_detection():
#     # Load the YOLO model
#     model = YOLO("yolov8s.pt")
    
#     # Open a file dialog for the user to select an image file
#     file_path = filedialog.askopenfilename()
    
#     # Check if a file was selected
#     if file_path:
#         # Perform object detection on the selected image
#         results = model.predict(source=file_path, conf=0.4, save=False)

#         # Display the processed image with bounding boxes
#         display_image(results.imgs[0])

# # Create a function to display the image with bounding boxes
# def display_image(image):
#     image = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2RGB)
#     photo = ImageTk.PhotoImage(image=Image.fromarray(image))

#     label = tk.Label(root, image=photo)
#     label.image = photo
#     label.pack()

# # Create the main application window
# root = tk.Tk()
# root.title("Object Detection GUI")

# # Create a button to trigger object detection
# detect_button = tk.Button(root, text="Detect Objects", command=perform_object_detection)
# detect_button.pack(pady=20)

# # Start the main event loop
# root.mainloop()
# Out:
# image 1/1 C:\Users\NIKSHA MAHAJAN\Pictures\Screenshots\Screenshot (480).png: 384x640 6 persons, 2 potted plants, 2 tvs, 305.6ms
# Speed: 3.0ms preprocess, 305.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_8312\3828909698.py", line 22, in perform_object_detection
#     display_image(results.imgs[0])
#                   ^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'imgs'

# %%
import tkinter as tk
from tkinter import filedialog
from ultralytics import YOLO
from PIL import Image, ImageTk
import cv2
import numpy as np

# Create a function to perform object detection
def perform_object_detection():
    # Load the YOLO model
    model = YOLO("yolov8s.pt")
    
    # Open a file dialog for the user to select an image file
    file_path = filedialog.askopenfilename()
    
    # Check if a file was selected
    if file_path:
        # Perform object detection on the selected image
        results = model.predict(file_path, conf=0.4)
        
        # Extract the image with bounding boxes
        img_with_boxes = results.render()[0]

        # Display the processed image with bounding boxes
        display_image(img_with_boxes)

# Create a function to display the image with bounding boxes
def display_image(image):
    image = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2RGB)
    photo = ImageTk.PhotoImage(image=Image.fromarray(image))

    label = tk.Label(root, image=photo)
    label.image = photo
    label.pack()

# Create the main application window
root = tk.Tk()
root.title("Object Detection GUI")

# Create a button to trigger object detection
detect_button = tk.Button(root, text="Detect Objects", command=perform_object_detection)
detect_button.pack(pady=20)

# Start the main event loop
root.mainloop()
# Out:
# image 1/1 C:\Users\NIKSHA MAHAJAN\Pictures\Screenshots\Screenshot (485).png: 384x640 1 person, 288.7ms
# Speed: 3.0ms preprocess, 288.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\NIKSHA MAHAJAN\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\NIKSHA MAHAJAN\AppData\Local\Temp\ipykernel_8312\2442534512.py", line 22, in perform_object_detection
#     img_with_boxes = results.render()[0]
#                      ^^^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'render'

# %%
# import cv2
# import tkinter as tk
# from ultralytics import YOLO
# from ultralytics.yolo.v8.detect.predict import DetectionPredictor
# from tkinter import filedialog
# from PIL import Image, ImageTk

# # Initialize the GUI
# root = tk.Tk()
# root.title("Object Detection GUI")

# # Create a function to perform object detection
# def detect_objects():
#     # Open a file dialog to select an image
#     file_path = filedialog.askopenfilename()
    
#     if file_path:
#         # Load and process the image using OpenCV
#         image = cv2.imread(file_path)
        
#         # Perform object detection here (using OpenCV, TensorFlow, or other libraries)
#         model = YOLO("yolov8s.pt")
#         results = model.predict( show=True , conf=0.4, save=True) 

#         # Display the processed image with detected objects in the GUI
#         display_image(image)

# # Create a function to display the image in the GUI
# def display_image(image):
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     image = Image.fromarray(image)
#     photo = ImageTk.PhotoImage(image=image)

#     label = tk.Label(image=photo)
#     label.image = photo
#     label.pack()

# # Create a button to trigger object detection
# detect_button = tk.Button(root, text="Detect Objects", command=detect_objects)
# detect_button.pack()

# # Start the GUI application
# root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 4
#       2 import tkinter as tk
#       3 from ultralytics import YOLO
# ----> 4 from ultralytics.yolo.v8.detect.predict import DetectionPredictor
#       5 from tkinter import filedialog
#       6 from PIL import Image, ImageTk
#
# ModuleNotFoundError: No module named 'ultralytics.yolo'

# %%
# !pip3 install ultralytics
